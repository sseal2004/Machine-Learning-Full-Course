# %% [markdown]
# Why Seaborn?
# 1. provide a layer of abstraction hence simple to use
#
# 2. better asesthetic
#
# 3. more graphs included

# %% [markdown]
# Seaborn Roadmap:
#
# Types of Function:
# 1. Figure Level
# 2. Axis Level
#
# Main Classification:
#
# 1. Relational Plot - Scatter ,Line
#
# 2. Distribution Plot - Histogram ,Kdeplot,Rugplot
#
# 3. Categorical Plot - BarPlot,CountPlot,BoxPlot,Violin Plot,Swanglet
#
# 4. Regression Plot -
#
# 5. Matrix Plot - HeatMap,Cluster Map
#
# 6. Multiplots - JointPlot , PairPlot
