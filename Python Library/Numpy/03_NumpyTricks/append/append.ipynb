# %%
import numpy as np
a= np.random.randint(1,100,15)
a
# Out:
# array([98, 74, 69,  2, 48,  2, 99, 25, 51, 13, 30,  4,  1,  5, 89],
#       dtype=int32)

# %%
b=np.random.randint(1,100,24).reshape(6,4)
b
# Out:
# array([[34, 47, 76, 12],
#        [73,  8, 38, 88],
#        [44,  7, 67, 97],
#        [ 5, 48, 99, 46],
#        [39, 25, 73, 20],
#        [33, 23, 43, 47]], dtype=int32)

# %%
#np.append

# %%
# It basically append the values along the mentioned axis at the end of the array

# %%
a
# Out:
# array([98, 74, 69,  2, 48,  2, 99, 25, 51, 13, 30,  4,  1,  5, 89],
#       dtype=int32)

# %%
np.append(a,200) # ifv u want to insert or append 200
# Out:
# array([ 98,  74,  69,   2,  48,   2,  99,  25,  51,  13,  30,   4,   1,
#          5,  89, 200])

# %%
np.append(b,np.ones((b.shape[0],1)))# append 1 at the row all
# Out:
# array([34., 47., 76., 12., 73.,  8., 38., 88., 44.,  7., 67., 97.,  5.,
#        48., 99., 46., 39., 25., 73., 20., 33., 23., 43., 47.,  1.,  1.,
#         1.,  1.,  1.,  1.])

# %%
np.append(b,np.ones((b.shape[0],1)),axis=1)# append 1 at the column all
# Out:
# array([[34., 47., 76., 12.,  1.],
#        [73.,  8., 38., 88.,  1.],
#        [44.,  7., 67., 97.,  1.],
#        [ 5., 48., 99., 46.,  1.],
#        [39., 25., 73., 20.,  1.],
#        [33., 23., 43., 47.,  1.]])
