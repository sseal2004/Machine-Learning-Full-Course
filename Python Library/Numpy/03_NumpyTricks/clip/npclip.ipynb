# %%
import numpy as np

# %%
a= np.random.randint(1,100,15)
a
# Out:
# array([97, 43, 10, 78, 86, 10, 73, 91, 73, 74, 76, 70, 10, 20, 65],
#       dtype=int32)

# %%
#set range 1 to 50

# %%
np.clip(a,a_min=1,a_max=50)
# Out:
# array([50, 43, 10, 50, 50, 10, 50, 50, 50, 50, 50, 50, 10, 20, 50],
#       dtype=int32)
