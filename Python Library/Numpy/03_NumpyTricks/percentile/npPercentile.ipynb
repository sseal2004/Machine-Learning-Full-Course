# %%
# Function used to compute the percentile of the given data along the specific axis.

# %%
import numpy as np
a= np.random.randint(1,100,15)
a
# Out:
# array([63, 52,  9, 96, 27, 51, 74, 10, 50, 21, 27, 33, 41, 58, 76],
#       dtype=int32)

# %%
b=np.random.randint(1,100,24).reshape(6,4)
b
# Out:
# array([[51, 57, 23, 95],
#        [57, 54,  9, 68],
#        [17, 12, 57, 40],
#        [46, 59, 88, 17],
#        [36, 89, 75, 70],
#        [42, 91, 33, 89]], dtype=int32)

# %%
print(np.percentile(a,100))
# Out:
# 96.0

# %%
print(np.percentile(a,50))
# Out:
# 50.0

# %%
print(np.median(a))
# Out:
# 50.0

# %%
print(np.percentile(a,0))
# Out:
# 9.0
