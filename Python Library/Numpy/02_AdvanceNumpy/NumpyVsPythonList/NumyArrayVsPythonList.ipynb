# %%
import numpy as np

# %%
#speed
#list
a = [i for i in range(10000000)]
b = [i for i in range(10000000)]
#so we have made two list now let's do add in item wise and put it into third list
c=[]
import time
start =time.time()
for i in range(len(a)):
    c.append(a[i]+b[i])

print(time.time()-start)
# Out:
# 2.5762271881103516

# %%
#numpy (same work in numpy array)
import numpy as np
import time

a = np.arange(1_000_000)
b = np.arange(1_000_000, 2_000_000)

start = time.time()
c = a + b
print("NumPy time:", time.time() - start)
# Out:
# NumPy time: 1.2322278022766113

# %%
#memory
import numpy as np

a = np.arange(10_000_000)
print(a.nbytes)   # actual data memory
# Out:
# 80000000

# %%
import sys
a = np.arange(10000000,dtype=np.int32)
sys.getsizeof(a)
# Out:
# 40000112
