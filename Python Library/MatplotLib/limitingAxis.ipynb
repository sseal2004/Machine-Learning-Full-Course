# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#style
plt.style.use('classic')

# %%
price = [40000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]
plt.plot(year,price)

# %% [markdown]
# LIMIT

# %%
#defining range
price = [40000,54000,57000,49000,47000,45000,470000]
year = [2015,2016,2017,2018,2019,2020,2027]
plt.plot(year,price)
plt.ylim(0,100000)
# Out:
# (0.0, 100000.0)

# %%
price = [40000,54000,57000,49000,47000,45000,470000]
year = [2015,2016,2017,2018,2019,2020,2027]
plt.plot(year,price)
plt.xlim(2019,2027)
# Out:
# (2019.0, 2027.0)

# %% [markdown]
# GRID

# %%
batsman = pd.read_csv('../MatplotLib/dataSets/sharma-kohli.csv')
batsman
plt.plot(batsman['index'],batsman['V Kohli'])
plt.grid()
