# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#style
plt.style.use('classic')

# %% [markdown]
# SCATTER PLOTS

# %% [markdown]
# 1.BIVARITE ANALYSIS
# 2.NUMERICAL VS NUMERICAL
# 3.USE CASE - FINDING CORRELATION

# %% [markdown]
# ACTUALLY 2D Plot is a Special Case of Scatter Plots

# %% [markdown]
# FUNCTION

# %%
x = np.linspace(-10,10,50)

# %%
y = 10*x + 3 +np.random.randint(0,300,50)
y
# Out:
# array([-47.        , -91.91836735,  46.16326531, 200.24489796,
#        151.32653061, -38.59183673, -39.51020408, 224.57142857,
#         -4.34693878, 196.73469388,  40.81632653, 218.89795918,
#         75.97959184, -35.93877551, 227.14285714, 145.2244898 ,
#        134.30612245,  93.3877551 , 124.46938776, 114.55102041,
#        131.63265306, 128.71428571, 256.79591837,  64.87755102,
#        123.95918367, 138.04081633, 182.12244898, 125.20408163,
#        107.28571429, 119.36734694, 281.44897959, 144.53061224,
#         46.6122449 , 303.69387755, 136.7755102 , 132.85714286,
#        209.93877551, 231.02040816, 192.10204082, 222.18367347,
#        306.26530612, 225.34693878, 158.42857143,  98.51020408,
#        344.59183673, 235.67346939, 288.75510204, 290.83673469,
#        375.91836735, 247.        ])

# %% [markdown]
# SCATTER PLOTTING

# %%
plt.scatter(x,y)

# %% [markdown]
# Scatter plot on Pandas Data(Proper DataSet)
