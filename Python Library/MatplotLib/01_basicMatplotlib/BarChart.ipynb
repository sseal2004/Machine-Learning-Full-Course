# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#style
plt.style.use('classic')

# %% [markdown]
# Types BARCHART :
# 1. Bivariate Analysis
# 2.Numerical Vs Categorical
# 3.Use case -Aggreagate analysis of groups

# %%
#simple bar chart
childern = [10,20,40,10,30]
colors=['red','blue','green','yellow','pink']
plt.bar(colors,childern,color='black')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(colors,childern,color='black')
# Out:
# <BarContainer object of 5 artists>

# %%
#color and label
df = pd.read_csv('./dataSets/batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %% [markdown]
# Bar chart

# %%
plt.bar(df['batsman'],df['2015'])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Overlaping bar chart

# %%
plt.bar(df['batsman'],df['2015'])
plt.bar(df['batsman'],df['2016'])
plt.bar(df['batsman'],df['2017'])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Side by side bar plots

# %%
x = np.arange(df.shape[0])
width = 0.25

plt.bar(x - width, df['2015'], width=width, label='2015')
plt.bar(x,         df['2016'], width=width, label='2016')
plt.bar(x + width, df['2017'], width=width, label='2017')


plt.xticks(x, df['batsman'])   # if df.index contains labels
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Comparison of Data from 2015 to 2017")
plt.legend()

plt.show()

# %% [markdown]
# PROBLEM

# %% [markdown]
# If it has categorical large name

# %%
#simple bar chart
childern = [10,20,40,10,30]
colors=['red red red red','blue blue blue','green green green green green','yellow yellow','pink pink pink']
plt.bar(colors,childern,color='black')
# Out:
# <BarContainer object of 5 artists>

# %%
childern = [10,20,40,10,30]
colors=['red red red red','blue blue blue','green green green green green','yellow yellow','pink pink pink']
plt.bar(colors,childern,color='black')
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'red red red red'),
#   Text(1, 0, 'blue blue blue'),
#   Text(2, 0, 'green green green green green'),
#   Text(3, 0, 'yellow yellow'),
#   Text(4, 0, 'pink pink pink')])

# %% [markdown]
# STACK BAR CHART

# %%
df #dataSet of 5 batsman
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(df['batsman'], df['2015'], label='2015')
plt.bar(df['batsman'], df['2016'], bottom=df['2015'], label='2016')
plt.bar(
    df['batsman'],
    df['2017'],
    bottom=df['2015'] + df['2016'],
    label='2017'
)

plt.xlabel("Batsman")
plt.ylabel("Runs")
plt.title("Runs scored by Batsmen (2015–2017)")
plt.legend()
plt.show()
