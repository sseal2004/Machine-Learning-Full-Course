# %%
import numpy as np
import pandas as pd

# %%
movies =pd.read_csv('bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
vk =pd.read_csv('kohli_ipl.csv',index_col='match_no').squeeze().sort_values(ascending=True)
vk
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
subs = pd.read_csv('subs.csv')
subs.sort_values(by='Subscribers gained', ascending=True)
# Out:
#      Subscribers gained
# 42                   33
# 6                    33
# 24                   35
# 19                   37
# 14                   39
# ..                  ...
# 280                 295
# 233                 301
# 168                 306
# 331                 312
# 330                 396
#
# [365 rows x 1 columns]

# %% [markdown]
# PLOTTING GRAPHS ON SERIES

# %%
subs.plot()
# Out:
# <Axes: >

# %% [markdown]
# TOP 20 ACTORS FROM MOVIES

# %%
plot_movies = movies.value_counts().head(20)
plot_movies
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# John Abraham        18
# Saif Ali Khan       18
# Shahid Kapoor       17
# Sunny Deol          17
# Jimmy Sheirgill     16
# Tusshar Kapoor      16
# Irrfan Khan         14
# Arjun Rampal        14
# Manoj Bajpayee      14
# Anupam Kher         13
# Hrithik Roshan      12
# Naseeruddin Shah    12
# Kangana Ranaut      12
# Name: count, dtype: int64

# %%
plot_movies.plot(kind='pie')# pie chart plotting
# Out:
# <Axes: ylabel='count'>

# %%
plot_movies.plot(kind='bar')# bar chart plotting
# Out:
# <Axes: xlabel='lead'>
