# %%
import numpy as np
import pandas as pd

# %%
#Series From Dict

# %%
marks = {
    'math':67,
    'english':57,
    'science':89,
    'html':100
}
marks_series = pd.Series(marks)
marks_series
# Out:
# math        67
# english     57
# science     89
# html       100
# dtype: int64

# %%
#size

# %%
marks_series.size
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#isuique

# %%
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
#index
marks_series.index
# Out:
# Index(['math', 'english', 'science', 'html'], dtype='object')

# %%
runs = [13,24,56,78,100]
pd.Series(runs)
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
runs.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %%
#Type
type(marks_series.values)
# Out:
# numpy.ndarray
